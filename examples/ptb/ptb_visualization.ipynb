# %% [markdown]
# This notebook requires the user to have installed tsne and mpld3 with:
#
#     pip install mpld3
#     pip install tsne

# %%
from __future__ import division
import numpy as np
import pickle
from tsne import bh_sne
# %matplotlib inline
import matplotlib.pyplot as plt
import math
import lmdb
import itertools

import mpld3
mpld3.enable_notebook()
from mpld3 import plugins

# Make sure that caffe is on the python path:
caffe_root = '../../'  # this file is expected to be in {caffe_root}/examples/ptb
import sys
sys.path.insert(0, caffe_root + 'python')
import caffe
sys.path.insert(0, caffe_root + 'python/caffe/proto')
import caffe_pb2
sys.path.insert(0, caffe_root + 'examples/ptb')
import create_ptb

# %%
base_param = create_ptb.get_base_param()
model_folder = 'caffe_merge'
caffe.set_mode_gpu()
net = caffe.Classifier(caffe_root + 'examples/ptb/deploy.prototxt',
                       caffe_root + 'examples/ptb/ptb_iter_10000.caffemodel')

# %%
def get_datums():
    env = lmdb.open(caffe_root + 'examples/ptb/ptb_test_db')
    with env.begin() as txn:
        cursor = txn.cursor()
        while cursor.next():
            datum = caffe_pb2.Datum()
            datum.ParseFromString(cursor.value())
            yield datum

# %%
fast_test = False
if fast_test:   
    datums = list(itertools.islice(get_datums(), 1000))
else:
    datums = list(get_datums())

# %%
def get_data(datums):
    n = datums[0].channels // 2
    for i in range(0, len(datums), base_param['deploy_batch_size']):
        data = np.zeros((base_param['deploy_batch_size'], 2 * n, 1, 1))
        for j in range(base_param['deploy_batch_size']):
            if (i + j) >= len(datums):
                return
            data[j, :, 0, 0] = datums[i + j].float_data
        yield data

data_batches = list(get_data(datums))

# %%
def score_sentence(datum, net, net_id):
    n = datum.channels // 2
    loss = np.zeros(n,)
    length = 0
    for i in range(n):
        target_category_id = int(net.blobs['target'].data[net_id, i].flatten()[0])
        if target_category_id == base_param['t_zero_symbol']:
            break
        length += 1
        loss[i] = -math.log(net.blobs['word_probs'].data[net_id + base_param['deploy_batch_size'] * i, target_category_id])

    return loss, length

# %%
losses = []
lengths = []
for i, batch in enumerate(data_batches):
    net.rff(batch)
    for j in range(len(batch)):
        datum = datums[j + base_param['deploy_batch_size'] * i] 
        loss, length = score_sentence(datum, net, j)
        losses.append(loss)        
        lengths.append(length)
    print 'loss: %s' % (np.sum(losses) / sum(lengths))
print 'Final perplexity %s' % math.exp(np.sum(losses) / sum(lengs))
# Out:
# loss: 5.05762578285
# loss: 4.93134688545
# loss: 5.02269289037
# loss: 4.99097074407
# loss: 5.01316046805
# loss: 5.0228466916
# loss: 5.04019975571
# loss: 4.92778633627
# loss: 4.89915342792
# loss: 4.89396941806
# loss: 4.88838767024
# loss: 4.87810868641
# loss: 4.86910140603
# loss: 4.87590223926
# loss: 4.90878642451
# loss: 4.92268864832
# loss: 4.93711731207
# loss: 4.96071754
# loss: 4.94959890959
# loss: 4.95448707061
# loss: 4.9349744747
# loss: 4.93782812469
# loss: 4.93750092117
# loss: 4.93939578616
# loss: 4.93572721877
# loss: 4.93638753742
# loss: 4.91432575094
# loss: 4.90094381137
# loss: 4.91204987973
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-16-00c1c46dadaa> in <module>()
#       9         lengths.append(length)
#      10     print 'loss: %s' % (np.sum(losses) / sum(lengths))
# ---> 11 print 'Final perplexity %s' % math.exp(np.sum(losses) / sum(lengs))
#
# NameError: name 'lengs' is not defined

# %%
vocab = pickle.load(open(caffe_root + 'data/ptb/vocab.pkl', 'r'))
inv = lambda d: {v:k for k,v in d.iteritems()}
vocab_inv = inv(vocab)

# %%
word_vectors = {k:net.params['target_wordvec_layer'][0].data[0, vocab[k], 0, :] for (k, v) in vocab.items() if v < base_param['target_vocab_size']}
print sorted(word_vectors.keys(), key= lambda x: np.linalg.norm(word_vectors['four'] - word_vectors[x]))[:100]
# Out:
# ['four', 'seven', 'eight', 'ten', 'five', 'hundred', 'unscrupulous', 'numerous', 'eighth', 'dumped', 'jailed', 'liberal', 'six', 'three', 'frozen', 'printed', 'twelve', 'mood', 'year-to-year', 'cheapest', 'reaches', 'marched', 'parallel', 'chlorofluorocarbons', 'livestock', 'propelled', 'ramirez', 'lean', 'inch', 'tours', 'crystal', 'several', 'composed', 'tailored', 'richer', 'unidentified', 'pearce', 'glamorous', 'pertussis', 'comfort', 'carter', 'abundant', 'piano', 'lighter', 'endless', 'boat', 'generic', 'boyd', 'lovely', 'unprofitable', 'broker-dealer', 'mode', 'fan', 'tires', 'lumber', 'gestures', 'portrayal', 'joan', 'measurement', 'precise', 'gradual', 'handy', 'fraction', 'hire', 'farrell', 'outperformed', 'stir', 'favorite', 'gregory', 'entrenched', 'pesetas', 'regular-season', 'displayed', 'painful', 'rebates', 'identical', 'lesk', 'tony', 'warehouse', 'thrown', 'giorgio', 'dialysis', 'campus', 'low-income', 'hollander', 'pitched', 'lure', 'karen', 'defective', 'tap', 'narrower', 'twist', 'tall', 'proliferation', 'oldest', 'repaired', 'cubic', 'tumultuous', 'kronor', 'bellwether']

# %%
M = np.zeros((len(word_vectors), len(word_vectors.values()[0].flatten())))
for k, v in word_vectors.items():
    M[vocab[k], :] = v
    
X_2d = bh_sne(M)

# %%
fig, ax = plt.subplots(subplot_kw=dict(axisbg='#EEEEEE'), figsize=(8,8))
ax.grid(color='white', linestyle='solid')

num_words_to_plot = 500

scatter = ax.scatter(X_2d[:num_words_to_plot, 0], X_2d[:num_words_to_plot, 1], s = 100, c='#3EEEEE', alpha=0.1, cmap=plt.cm.jet)
labels = [vocab_inv[i] for i in range(num_words_to_plot)]
plugins.connect(fig, plugins.PointLabelTooltip(scatter, labels))
